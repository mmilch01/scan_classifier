# %%
tags=[\
      'SeriesInstanceUID','Modality','Manufacturer','StudyDescription','SeriesDescription','ManufacturerModelName',\
        'BodyPartExamined','ScanningSequence','SequenceVariant','MRAcquisitionType',\
        'SequenceName','ScanOptions','SliceThickness','RepetitionTime','EchoTime','InversionTime',\
        'MagneticFieldStrength','NumberOfPhaseEncodingSteps','EchoTrainLength','PercentSampling',\
        'PercentPhaseFieldOfView','PixelBandwidth','AcquisitionMatrix','ImageType',\
        'FlipAngle','VariableFlipAngleFlag','PatientPosition','PhotometricInterpretation','Rows',\
        'Columns','PixelSpacing','ContrastBolusVolume','ContrastBolusTotalDose',\
        'ContrastBolusIngredient','ContrastBolusIngredientConcentration',\
        'PatientOrientation','ImageLaterality','ImageComments','ImagePositionPatient',\
        'ImageOrientationPatient','SamplesPerPixel','PhotometricInterpretation',\
        'PlanarConfiguration','PixelAspectRatio','BitsAllocated','BitsStored','HighBit',\
        'PixelRepresentation','ColorSpace','AngioFlag','ImagingFrequency','EchoNumbers',\
        'SpacingBetweenSlices','TriggerTime','NominalInterval','BeatRejectionFlag','LowRRValue',\
        'HighRRValue','IntervalsAcquired','PVCRejection','SkipBeats','HeartRate','TriggerWindow',\
        'ReconstructionDiameter','ReceiveCoilName','TransmitCoilName','InPlanePhaseEncodingDirection',\
        'SAR','dBdt', 'B1rms', 'TemporalPositionIdentifier', 'NumberOfTemporalPositions', 'TemporalResolution',\
        'SliceProgressionDirection','IsocenterPosition', \
         \
         'KVP','DataCollectionDiameter','DistanceSourceToDetector','DistanceSourceToPatient',\
         'GantryDetectorTilt','TableHeight','RotationDirection','ExposureTime','XRayTubeCurrent','Exposure',\
         'ImageAndFluoroscopyAreaDoseProduct','FilterType','GeneratorPower','FocalSpots','ConvolutionKernel',\
         'WaterEquivalentDiameter','RevolutionTime','SingleCollimationWidth','TotalCollimationWidth',\
         'TableSpeed','TableFeedPerRotation','SpiralPitchFactor','DataCollectionCenterPatient',\
         'ReconstructionTargetCenterPatient','ExposureModulationType','EstimatedDoseSaving',\
         'CTDIvol','CalciumScoringMassFactorPatient','CalciumScoringMassFactorDevice','EnergyWeightingFactor',\
         'MultienergyCTAcquisition','AcquisitionNumber','RescaleIntercept','RescaleSlope',\
         'PatientSupportAngle','TableTopLongitudinalPosition','TableTopLateralPosition',\
         'TableTopPitchAngle','TableTopRollAngle',\
      \
      'StageName','StageNumber','NumberOfStages','ViewName','ViewNumber','NumberOfEventTimers',\
      'NumberOfViewsInStage','EventElapsedTimes','EventTimerNames','HeartRate','IVUSAcquisition','IVUSPullbackRate','IVUSGatedRate',\
      'TransducerType','FocusDepth','MechanicalIndex','BoneThermalIndex','CranialThermalIndex',\
      'SoftTissueThermalIndex','SoftTissueFocusThermalIndex','DepthOfScanField',\
      \
      'ExposureInuAs','AcquisitionDeviceProcessingDescription','AcquisitionDeviceProcessingCode',\
      'CassetteOrientation','CassetteSize','ExposuresOnPlate','RelativeXRayExposure','ExposureIndex',\
      'TargetExposureIndex','DeviationIndex','Sensitivity','PixelSpacingCalibrationType','PixelSpacingCalibrationDescription',\
      'DerivationDescription','AcquisitionDeviceProcessingDescription','AcquisitionDeviceProcessingCode',\
      'RescaleType','WindowCenterWidthExplanation','CalibrationImage','PresentationLUTShape',\
     \
      'PlateID','CassetteID','FieldOfViewShape','FieldOfViewDimensions','ImagerPixelSpacing',\
      'ExposureIndex','TargetExposureIndex','DeviationIndex','Sensitivity','DetectorConditionsNominalFlag',\
      'DetectorTemperature','DetectorType','DetectorConfiguration','DetectorDescription','DetectorMode',\
      'DetectorBinning','DetectorElementPhysicalSize','DetectorElementSpacing','DetectorActiveShape',\
      'DetectorActiveDimensions','DetectorActiveOrigin','DetectorManufacturerName','DetectorManufacturerModelName',\
      'FieldOfViewOrigin','FieldOfViewRotation','FieldOfViewHorizontalFlip','PixelSpacingCalibrationType',\
      'PixelSpacingCalibrationDescription',\
      \
      'PrimaryPromptsCountsAccumulated','SecondaryCountsAccumulated','SliceSensitivityFactor',\
      'DecayFactor','DoseCalibrationFactor','ScatterFractionFactor','DeadTimeFactor','IsocenterPosition',\
      'PatientGantryRelationshipCodeSequence','TriggerSourceOrType','CardiacFramingType','PVCRejection',\
      'CollimatorGridName','CollimatorType','CorrectedImage','TypeOfDetectorMotion','Units','CountsSource',\
      'ReprojectionMethod','SUVType','RandomsCorrectionMethod','RandomsCorrectionMethod','DecayCorrection',\
      'ReconstructionMethod','DetectorLinesOfResponseUsed','ScatterCorrectionMethod','ScatterCorrectionMethod',\
      'AxialMash','TransverseMash','CoincidenceWindowWidth','SecondaryCountsType',\
      \
      'PositionerType','PositionerPrimaryAngle','PositionerSecondaryAngle','PositionerPrimaryAngleDirection',\
      'ImageLaterality','BreastImplantPresent','PartialView','PartialViewDescription','OrganExposed'\
     ]

tags=list(set(tags))
tags.sort()

# %%
import pydicom

def get_first_files(dir_in,dir_out,tags):
    ndirs=0
    for root, dirs, files in os.walk(dir_in):
        if files:
            first_file = os.path.join(root, files[0])
            #this may happen because we have config file also in the same dir, and order is random
            try:
                if pydicom.misc.is_dicom(first_file):
                    #if ndirs % 1000 == 0: print('{} DICOM files written'.format(ndirs))
                    ndirs=ndirs+1                                
                    #print('found DICOM file:',first_file)
                    ds=pydicom.filereader.dcmread(first_file,stop_before_pixels=True,specific_tags=tags)
                    outfil=dir_out+'/'+pydicom.uid.generate_uid()+'.dcm'                    
                    #print('writing:',outfil)
                    pydicom.filewriter.dcmwrite(outfil,ds)
            except Exception as e:
                print('error reading',first_file)

def process_dir(src,targ,files):
    #first_file = os.path.join(src, file)
    #print(first_file)
    existing_suids=set()
    for file in files:
        try:
            fil=src+'/'+file
            if pydicom.misc.is_dicom(fil):
            #if ndirs % 1000 == 0: print('{} DICOM files written'.format(ndirs))
            #ndirs=ndirs+1                                
            #print('found DICOM file:',first_file)                
                ds=pydicom.filereader.dcmread(fil,stop_before_pixels=True,specific_tags=tags)                
                suid=ds['SeriesInstanceUID'].value
                #print(suid)
                if suid not in existing_suids:                
                    outfil=targ+'/'+pydicom.uid.generate_uid()+'.dcm'
                    #print('writing:',outfil)
                    del ds.SeriesInstanceUID
                    pydicom.filewriter.dcmwrite(outfil,ds)
                    existing_suids.add(suid)                    
                #else:
                    #print(suid+'already processed')
        except Exception as e:
            print('Not a DICOM file:',fil)

def create_dir(d):
    if not os.path.exists(d):
        os.makedirs(d)

# %%
data_dir='/data/ImagingCommons/data1'
temp_dir='/home/mmilchenko/temp/ImagingCommons'
start = time.time()
#files=os.listdir(temp_dir)  
get_first_files(temp_dir,data_dir,tags)
print(time.time()-start)

# %%
start = time.time()
shutil.rmtree(temp_dir)
print(time.time()-start)

# %%
#read the input file.
import csv,os,glob,time,shutil

data_dir='/data/ImagingCommons/dataX'
temp_dir='/home/mmilchenko/temp/ImagingCommons'
nser=0
start = time.time()
batch_size=100
batch_pos=0

start_ser=0
end_ser=65601
create_dir(data_dir)
create_dir(temp_dir)

nbatch=0
with open('/data/ImagingCommons/cohort_1043_20230606_93426_failed_cases.csv', newline='') as csvfile:
    #1. create download batch.         
    r = csv.reader(csvfile, delimiter=',', quotechar='|')    
    for row in r:
        nser+=1
        if nser < start_ser: continue
        if nser > end_ser: break
        ser=row[6]
        if batch_pos == batch_size:
            nser-=1
            nbatch+=1
            print('processing batch',nbatch)
            #break
            os.system("s5cmd --no-sign-request --endpoint-url https://storage.googleapis.com run {}/temp.s5cmd".format(temp_dir))
            #files=os.listdir(temp_dir)
            get_first_files(temp_dir,data_dir,tags)
            #process_dir(temp_dir,data_dir,files)            
            #os.system("rm {}/*".format(temp_dir))
            #for f in files: os.remove(temp_dir+'/'+f) 
            #print('done')
            
            nsec=time.time()-start
            nhour=int(nsec/3600)
            nmin=int((int(nsec) %3600)/60)
            nsec=int(nsec) % 60
            print ('written {} dcm files, time elapsed: {}h {}m {}s'.format(nser,nhour,nmin,nsec))                                    
            
            shutil.rmtree(temp_dir)
            #shutil over-zealosly removes top dir without any option
            create_dir(temp_dir)
            batch_pos=0
        else:
            #print("mkdir -p {}/{}".format(temp_dir,ser))
            os.system("mkdir -p {}/{}".format(temp_dir,ser))
            os.system("echo cp s3://public-datasets-idc/{}/* {}/{}/>>{}/temp.s5cmd".format(ser,temp_dir,ser,temp_dir))
            batch_pos+=1  
            
shutil.rmtree(temp_dir)
# Out:
# processing batch 1
# written 100 dcm files, time elapsed: 0h 0m 39s
# processing batch 2
# written 200 dcm files, time elapsed: 0h 1m 20s
# processing batch 3
# written 300 dcm files, time elapsed: 0h 2m 4s
# processing batch 4
# written 400 dcm files, time elapsed: 0h 2m 48s
# processing batch 5
# written 500 dcm files, time elapsed: 0h 3m 28s
# processing batch 6
# written 600 dcm files, time elapsed: 0h 4m 7s
# processing batch 7
# written 700 dcm files, time elapsed: 0h 4m 52s
# processing batch 8
# written 800 dcm files, time elapsed: 0h 5m 38s
# processing batch 9
# written 900 dcm files, time elapsed: 0h 6m 25s
# processing batch 10
# written 1000 dcm files, time elapsed: 0h 7m 9s
# processing batch 11
# written 1100 dcm files, time elapsed: 0h 7m 51s
# processing batch 12
# written 1200 dcm files, time elapsed: 0h 8m 35s
# processing batch 13
# written 1300 dcm files, time elapsed: 0h 9m 22s
# processing batch 14
# written 1400 dcm files, time elapsed: 0h 9m 57s
# processing batch 15
# written 1500 dcm files, time elapsed: 0h 10m 36s
# processing batch 16
# written 1600 dcm files, time elapsed: 0h 11m 13s
# processing batch 17
# written 1700 dcm files, time elapsed: 0h 11m 53s
# processing batch 18
# written 1800 dcm files, time elapsed: 0h 12m 33s
# processing batch 19
# written 1900 dcm files, time elapsed: 0h 13m 17s
# processing batch 20
# written 2000 dcm files, time elapsed: 0h 13m 55s
# processing batch 21
# written 2100 dcm files, time elapsed: 0h 14m 39s
# processing batch 22
# written 2200 dcm files, time elapsed: 0h 15m 26s
# processing batch 23
# written 2300 dcm files, time elapsed: 0h 16m 12s
# processing batch 24
# written 2400 dcm files, time elapsed: 0h 16m 53s
# processing batch 25
# written 2500 dcm files, time elapsed: 0h 17m 57s
# processing batch 26
# written 2600 dcm files, time elapsed: 0h 19m 10s
# processing batch 27
# written 2700 dcm files, time elapsed: 0h 20m 13s
# processing batch 28
# written 2800 dcm files, time elapsed: 0h 21m 26s
# processing batch 29
# written 2900 dcm files, time elapsed: 0h 22m 30s
# processing batch 30
# written 3000 dcm files, time elapsed: 0h 23m 41s
# processing batch 31
# written 3100 dcm files, time elapsed: 0h 24m 34s
# processing batch 32
# written 3200 dcm files, time elapsed: 0h 25m 14s
# processing batch 33
# written 3300 dcm files, time elapsed: 0h 25m 53s
# processing batch 34
# written 3400 dcm files, time elapsed: 0h 26m 46s
# processing batch 35
# written 3500 dcm files, time elapsed: 0h 27m 27s
# processing batch 36
# written 3600 dcm files, time elapsed: 0h 28m 19s
# processing batch 37
# written 3700 dcm files, time elapsed: 0h 28m 57s
# processing batch 38
# written 3800 dcm files, time elapsed: 0h 29m 18s
# processing batch 39
# written 3900 dcm files, time elapsed: 0h 29m 20s
# processing batch 40
# written 4000 dcm files, time elapsed: 0h 29m 22s
# processing batch 41
# written 4100 dcm files, time elapsed: 0h 29m 23s
# processing batch 42
# written 4200 dcm files, time elapsed: 0h 29m 25s
# processing batch 43
# written 4300 dcm files, time elapsed: 0h 29m 26s
# processing batch 44
# written 4400 dcm files, time elapsed: 0h 29m 27s
# processing batch 45
# written 4500 dcm files, time elapsed: 0h 29m 29s
# processing batch 46
# written 4600 dcm files, time elapsed: 0h 29m 30s
# processing batch 47
# written 4700 dcm files, time elapsed: 0h 29m 32s
# processing batch 48
# written 4800 dcm files, time elapsed: 0h 29m 33s
# processing batch 49
# written 4900 dcm files, time elapsed: 0h 29m 35s
# processing batch 50
# written 5000 dcm files, time elapsed: 0h 29m 36s
# processing batch 51
# written 5100 dcm files, time elapsed: 0h 29m 38s
# processing batch 52
# written 5200 dcm files, time elapsed: 0h 29m 39s
# processing batch 53
# written 5300 dcm files, time elapsed: 0h 29m 41s
# processing batch 54
# written 5400 dcm files, time elapsed: 0h 29m 42s
# processing batch 55
# written 5500 dcm files, time elapsed: 0h 29m 44s
# processing batch 56
# written 5600 dcm files, time elapsed: 0h 29m 45s
# processing batch 57
# written 5700 dcm files, time elapsed: 0h 29m 46s
# processing batch 58
# written 5800 dcm files, time elapsed: 0h 29m 48s
# processing batch 59
# written 5900 dcm files, time elapsed: 0h 29m 49s
# processing batch 60
# written 6000 dcm files, time elapsed: 0h 29m 50s
# processing batch 61
# written 6100 dcm files, time elapsed: 0h 29m 52s
# processing batch 62
# written 6200 dcm files, time elapsed: 0h 29m 54s
# processing batch 63
# written 6300 dcm files, time elapsed: 0h 29m 55s
# processing batch 64
# written 6400 dcm files, time elapsed: 0h 29m 56s
# processing batch 65
# written 6500 dcm files, time elapsed: 0h 29m 58s
# processing batch 66
# written 6600 dcm files, time elapsed: 0h 29m 59s
# processing batch 67
# written 6700 dcm files, time elapsed: 0h 30m 0s
# processing batch 68
# written 6800 dcm files, time elapsed: 0h 30m 1s
# processing batch 69
# written 6900 dcm files, time elapsed: 0h 30m 3s
# processing batch 70
# written 7000 dcm files, time elapsed: 0h 30m 4s
# processing batch 71
# written 7100 dcm files, time elapsed: 0h 30m 5s
# processing batch 72
# written 7200 dcm files, time elapsed: 0h 30m 7s
# processing batch 73
# written 7300 dcm files, time elapsed: 0h 30m 8s
# processing batch 74
# written 7400 dcm files, time elapsed: 0h 30m 9s
# processing batch 75
# written 7500 dcm files, time elapsed: 0h 30m 10s
# processing batch 76
# written 7600 dcm files, time elapsed: 0h 30m 12s
# processing batch 77
# written 7700 dcm files, time elapsed: 0h 30m 13s
# processing batch 78
# written 7800 dcm files, time elapsed: 0h 30m 15s
# processing batch 79
# written 7900 dcm files, time elapsed: 0h 30m 16s
# processing batch 80
# written 8000 dcm files, time elapsed: 0h 30m 17s
# processing batch 81
# written 8100 dcm files, time elapsed: 0h 30m 19s
# processing batch 82
# written 8200 dcm files, time elapsed: 0h 30m 20s
# processing batch 83
# written 8300 dcm files, time elapsed: 0h 30m 21s
# processing batch 84
# written 8400 dcm files, time elapsed: 0h 30m 23s
# processing batch 85
# written 8500 dcm files, time elapsed: 0h 30m 24s
# processing batch 86
# written 8600 dcm files, time elapsed: 0h 30m 25s
# processing batch 87
# written 8700 dcm files, time elapsed: 0h 30m 27s
# processing batch 88
# written 8800 dcm files, time elapsed: 0h 30m 28s
# processing batch 89
# written 8900 dcm files, time elapsed: 0h 30m 30s
# processing batch 90
# written 9000 dcm files, time elapsed: 0h 30m 31s
# processing batch 91
# written 9100 dcm files, time elapsed: 0h 30m 32s
# processing batch 92
# written 9200 dcm files, time elapsed: 0h 30m 34s
# processing batch 93
# written 9300 dcm files, time elapsed: 0h 30m 35s
# processing batch 94
# written 9400 dcm files, time elapsed: 0h 30m 36s
# processing batch 95
# written 9500 dcm files, time elapsed: 0h 30m 38s
# processing batch 96
# written 9600 dcm files, time elapsed: 0h 30m 39s
# processing batch 97
# written 9700 dcm files, time elapsed: 0h 30m 41s
# processing batch 98
# written 9800 dcm files, time elapsed: 0h 30m 42s
# processing batch 99
# written 9900 dcm files, time elapsed: 0h 30m 44s
# processing batch 100
# written 10000 dcm files, time elapsed: 0h 30m 45s
# processing batch 101
# written 10100 dcm files, time elapsed: 0h 30m 46s
# processing batch 102
# written 10200 dcm files, time elapsed: 0h 30m 48s
# processing batch 103
# written 10300 dcm files, time elapsed: 0h 30m 49s
# processing batch 104
# written 10400 dcm files, time elapsed: 0h 30m 51s
# processing batch 105
# written 10500 dcm files, time elapsed: 0h 30m 52s
# processing batch 106
# written 10600 dcm files, time elapsed: 0h 30m 53s
# processing batch 107
# written 10700 dcm files, time elapsed: 0h 30m 54s
# processing batch 108
# written 10800 dcm files, time elapsed: 0h 30m 56s
# processing batch 109
# written 10900 dcm files, time elapsed: 0h 30m 57s
# processing batch 110
# written 11000 dcm files, time elapsed: 0h 30m 59s
# processing batch 111
# written 11100 dcm files, time elapsed: 0h 31m 0s
# processing batch 112
# written 11200 dcm files, time elapsed: 0h 31m 2s
# processing batch 113
# written 11300 dcm files, time elapsed: 0h 31m 3s
# processing batch 114
# written 11400 dcm files, time elapsed: 0h 31m 4s
# processing batch 115
# written 11500 dcm files, time elapsed: 0h 31m 6s
# processing batch 116
# written 11600 dcm files, time elapsed: 0h 31m 7s
# processing batch 117
# written 11700 dcm files, time elapsed: 0h 31m 8s
# processing batch 118
# written 11800 dcm files, time elapsed: 0h 31m 10s
# processing batch 119
# written 11900 dcm files, time elapsed: 0h 31m 11s
# processing batch 120
# written 12000 dcm files, time elapsed: 0h 31m 13s
# processing batch 121
# written 12100 dcm files, time elapsed: 0h 31m 14s
# processing batch 122
# written 12200 dcm files, time elapsed: 0h 31m 15s
# processing batch 123
# written 12300 dcm files, time elapsed: 0h 31m 17s
# processing batch 124
# written 12400 dcm files, time elapsed: 0h 31m 18s
# processing batch 125
# written 12500 dcm files, time elapsed: 0h 31m 19s
# processing batch 126
# written 12600 dcm files, time elapsed: 0h 31m 20s
# processing batch 127
# written 12700 dcm files, time elapsed: 0h 31m 22s
# processing batch 128
# written 12800 dcm files, time elapsed: 0h 31m 23s
# processing batch 129
# written 12900 dcm files, time elapsed: 0h 31m 25s
# processing batch 130
# written 13000 dcm files, time elapsed: 0h 31m 26s
# processing batch 131
# written 13100 dcm files, time elapsed: 0h 31m 28s
# processing batch 132
# written 13200 dcm files, time elapsed: 0h 31m 29s
# processing batch 133
# written 13300 dcm files, time elapsed: 0h 31m 31s
# processing batch 134
# written 13400 dcm files, time elapsed: 0h 31m 32s
# processing batch 135
# written 13500 dcm files, time elapsed: 0h 31m 33s
# processing batch 136
# written 13600 dcm files, time elapsed: 0h 31m 35s
# processing batch 137
# written 13700 dcm files, time elapsed: 0h 31m 36s
# processing batch 138
# written 13800 dcm files, time elapsed: 0h 31m 38s
# processing batch 139
# written 13900 dcm files, time elapsed: 0h 31m 39s
# processing batch 140
# written 14000 dcm files, time elapsed: 0h 31m 41s
# processing batch 141
# written 14100 dcm files, time elapsed: 0h 31m 43s
# processing batch 142
# written 14200 dcm files, time elapsed: 0h 31m 45s
# processing batch 143
# written 14300 dcm files, time elapsed: 0h 31m 46s
# processing batch 144
# written 14400 dcm files, time elapsed: 0h 31m 47s
# processing batch 145
# written 14500 dcm files, time elapsed: 0h 31m 48s
# processing batch 146
# written 14600 dcm files, time elapsed: 0h 31m 50s
# processing batch 147
# written 14700 dcm files, time elapsed: 0h 31m 51s
# processing batch 148
# written 14800 dcm files, time elapsed: 0h 31m 53s
# processing batch 149
# written 14900 dcm files, time elapsed: 0h 31m 54s
# processing batch 150
# written 15000 dcm files, time elapsed: 0h 31m 55s
# processing batch 151
# written 15100 dcm files, time elapsed: 0h 31m 57s
# processing batch 152
# written 15200 dcm files, time elapsed: 0h 31m 58s
# processing batch 153
# written 15300 dcm files, time elapsed: 0h 31m 59s
# processing batch 154
# written 15400 dcm files, time elapsed: 0h 32m 0s
# processing batch 155
# written 15500 dcm files, time elapsed: 0h 32m 2s
# processing batch 156
# written 15600 dcm files, time elapsed: 0h 32m 3s
# processing batch 157
# written 15700 dcm files, time elapsed: 0h 32m 5s
# processing batch 158
# written 15800 dcm files, time elapsed: 0h 32m 6s
# processing batch 159
# written 15900 dcm files, time elapsed: 0h 32m 7s
# processing batch 160
# written 16000 dcm files, time elapsed: 0h 32m 9s
# processing batch 161
# written 16100 dcm files, time elapsed: 0h 32m 10s
# processing batch 162
# written 16200 dcm files, time elapsed: 0h 32m 11s
# processing batch 163
# written 16300 dcm files, time elapsed: 0h 32m 13s
# processing batch 164
# written 16400 dcm files, time elapsed: 0h 32m 14s
# processing batch 165
# written 16500 dcm files, time elapsed: 0h 32m 15s
# processing batch 166
# written 16600 dcm files, time elapsed: 0h 32m 17s
# processing batch 167
# written 16700 dcm files, time elapsed: 0h 32m 18s
# processing batch 168
# written 16800 dcm files, time elapsed: 0h 32m 20s
# processing batch 169
# written 16900 dcm files, time elapsed: 0h 32m 21s
# processing batch 170
# written 17000 dcm files, time elapsed: 0h 32m 22s
# processing batch 171
# written 17100 dcm files, time elapsed: 0h 32m 23s
# processing batch 172
# written 17200 dcm files, time elapsed: 0h 32m 25s
# processing batch 173
# written 17300 dcm files, time elapsed: 0h 32m 26s
# processing batch 174
# written 17400 dcm files, time elapsed: 0h 32m 27s
# processing batch 175
# written 17500 dcm files, time elapsed: 0h 32m 29s
# processing batch 176
# written 17600 dcm files, time elapsed: 0h 32m 30s
# processing batch 177
# written 17700 dcm files, time elapsed: 0h 32m 32s
# processing batch 178
# written 17800 dcm files, time elapsed: 0h 32m 33s
# processing batch 179
# written 17900 dcm files, time elapsed: 0h 32m 34s
# processing batch 180
# written 18000 dcm files, time elapsed: 0h 32m 36s
# processing batch 181
# written 18100 dcm files, time elapsed: 0h 32m 37s
# processing batch 182
# written 18200 dcm files, time elapsed: 0h 32m 38s
# processing batch 183
# written 18300 dcm files, time elapsed: 0h 32m 40s
# processing batch 184
# written 18400 dcm files, time elapsed: 0h 32m 41s
# processing batch 185
# written 18500 dcm files, time elapsed: 0h 32m 42s
# processing batch 186
# written 18600 dcm files, time elapsed: 0h 32m 43s
# processing batch 187
# written 18700 dcm files, time elapsed: 0h 32m 45s
# processing batch 188
# written 18800 dcm files, time elapsed: 0h 32m 46s
# processing batch 189
# written 18900 dcm files, time elapsed: 0h 32m 48s
# processing batch 190
# written 19000 dcm files, time elapsed: 0h 32m 49s
# processing batch 191
# written 19100 dcm files, time elapsed: 0h 32m 55s
# processing batch 192
# written 19200 dcm files, time elapsed: 0h 33m 7s
# processing batch 193
# written 19300 dcm files, time elapsed: 0h 33m 19s
# processing batch 194
# written 19400 dcm files, time elapsed: 0h 33m 33s
# processing batch 195
# written 19500 dcm files, time elapsed: 0h 34m 8s
# processing batch 196
# written 19600 dcm files, time elapsed: 0h 34m 40s
# processing batch 197
# written 19700 dcm files, time elapsed: 0h 35m 17s
# processing batch 198
# written 19800 dcm files, time elapsed: 0h 36m 0s
# processing batch 199
# written 19900 dcm files, time elapsed: 0h 36m 47s
# processing batch 200
# written 20000 dcm files, time elapsed: 0h 37m 30s
# processing batch 201
# written 20100 dcm files, time elapsed: 0h 38m 25s
# processing batch 202
# written 20200 dcm files, time elapsed: 0h 38m 33s
# processing batch 203
# written 20300 dcm files, time elapsed: 0h 38m 41s
# processing batch 204
# written 20400 dcm files, time elapsed: 0h 38m 48s
# processing batch 205
# written 20500 dcm files, time elapsed: 0h 38m 55s
# processing batch 206
# written 20600 dcm files, time elapsed: 0h 39m 3s
# processing batch 207
# written 20700 dcm files, time elapsed: 0h 39m 10s
# processing batch 208
# written 20800 dcm files, time elapsed: 0h 39m 18s
# processing batch 209
# written 20900 dcm files, time elapsed: 0h 39m 26s
# processing batch 210
# written 21000 dcm files, time elapsed: 0h 39m 33s
# processing batch 211
# written 21100 dcm files, time elapsed: 0h 39m 45s
# processing batch 212
# written 21200 dcm files, time elapsed: 0h 39m 52s
# processing batch 213
# written 21300 dcm files, time elapsed: 0h 40m 0s
# processing batch 214
# written 21400 dcm files, time elapsed: 0h 40m 6s
# processing batch 215
# written 21500 dcm files, time elapsed: 0h 40m 15s
# processing batch 216
# written 21600 dcm files, time elapsed: 0h 40m 24s
# processing batch 217
# written 21700 dcm files, time elapsed: 0h 40m 31s
# processing batch 218
# written 21800 dcm files, time elapsed: 0h 40m 38s
# processing batch 219
# written 21900 dcm files, time elapsed: 0h 40m 46s
# processing batch 220
# written 22000 dcm files, time elapsed: 0h 40m 54s
# processing batch 221
# written 22100 dcm files, time elapsed: 0h 41m 1s
# processing batch 222
# written 22200 dcm files, time elapsed: 0h 41m 9s
# processing batch 223
# written 22300 dcm files, time elapsed: 0h 41m 17s
# processing batch 224
# written 22400 dcm files, time elapsed: 0h 41m 25s
# processing batch 225
# written 22500 dcm files, time elapsed: 0h 41m 35s
# processing batch 226
# written 22600 dcm files, time elapsed: 0h 41m 43s
# processing batch 227
# written 22700 dcm files, time elapsed: 0h 41m 51s
# processing batch 228
# written 22800 dcm files, time elapsed: 0h 42m 1s
# processing batch 229
# written 22900 dcm files, time elapsed: 0h 42m 8s
# processing batch 230
# written 23000 dcm files, time elapsed: 0h 42m 17s
# processing batch 231
# written 23100 dcm files, time elapsed: 0h 42m 25s
# processing batch 232
# written 23200 dcm files, time elapsed: 0h 42m 33s
# processing batch 233
# written 23300 dcm files, time elapsed: 0h 42m 40s
# processing batch 234
# written 23400 dcm files, time elapsed: 0h 42m 58s
# processing batch 235
# written 23500 dcm files, time elapsed: 0h 43m 11s
# processing batch 236
# written 23600 dcm files, time elapsed: 0h 43m 23s
# processing batch 237
# written 23700 dcm files, time elapsed: 0h 43m 32s
# processing batch 238
# written 23800 dcm files, time elapsed: 0h 43m 40s
# processing batch 239
# written 23900 dcm files, time elapsed: 0h 43m 48s
# processing batch 240
# written 24000 dcm files, time elapsed: 0h 43m 55s
# processing batch 241
# written 24100 dcm files, time elapsed: 0h 44m 4s
# processing batch 242
# written 24200 dcm files, time elapsed: 0h 44m 11s
# processing batch 243
# written 24300 dcm files, time elapsed: 0h 44m 22s
# processing batch 244
# written 24400 dcm files, time elapsed: 0h 44m 33s
# processing batch 245
# written 24500 dcm files, time elapsed: 0h 44m 41s
# processing batch 246
# written 24600 dcm files, time elapsed: 0h 44m 52s
# processing batch 247
# written 24700 dcm files, time elapsed: 0h 45m 3s
# processing batch 248
# written 24800 dcm files, time elapsed: 0h 45m 12s
# processing batch 249
# written 24900 dcm files, time elapsed: 0h 45m 21s
# processing batch 250
# written 25000 dcm files, time elapsed: 0h 45m 32s
# processing batch 251
# written 25100 dcm files, time elapsed: 0h 45m 44s
# processing batch 252
# written 25200 dcm files, time elapsed: 0h 45m 51s
# processing batch 253
# written 25300 dcm files, time elapsed: 0h 46m 1s
# processing batch 254
# written 25400 dcm files, time elapsed: 0h 46m 8s
# processing batch 255
# written 25500 dcm files, time elapsed: 0h 46m 17s
# processing batch 256
# written 25600 dcm files, time elapsed: 0h 46m 25s
# processing batch 257
# written 25700 dcm files, time elapsed: 0h 46m 32s
# processing batch 258
# written 25800 dcm files, time elapsed: 0h 46m 56s
# processing batch 259
# written 25900 dcm files, time elapsed: 0h 47m 13s
# processing batch 260
# written 26000 dcm files, time elapsed: 0h 47m 22s
# processing batch 261
# written 26100 dcm files, time elapsed: 0h 47m 28s
# processing batch 262
# written 26200 dcm files, time elapsed: 0h 47m 35s
# processing batch 263
# written 26300 dcm files, time elapsed: 0h 47m 43s
# processing batch 264
# written 26400 dcm files, time elapsed: 0h 47m 54s
# processing batch 265
# written 26500 dcm files, time elapsed: 0h 48m 2s
# processing batch 266
# written 26600 dcm files, time elapsed: 0h 48m 16s
# processing batch 267
# written 26700 dcm files, time elapsed: 0h 48m 24s
# processing batch 268
# written 26800 dcm files, time elapsed: 0h 48m 33s
# processing batch 269
# /nrgpackages/packages/tensorflow2/lib/python3.7/site-packages/pydicom/charset.py:754: UserWarning: Unknown encoding 'ISO_IR' - using default encoding instead
#   _warn_about_invalid_encoding(encoding)
# /nrgpackages/packages/tensorflow2/lib/python3.7/site-packages/pydicom/charset.py:754: UserWarning: Unknown encoding '100' - using default encoding instead
#   _warn_about_invalid_encoding(encoding)
# written 26900 dcm files, time elapsed: 0h 48m 49s
# processing batch 270
# written 27000 dcm files, time elapsed: 0h 49m 0s
# processing batch 271
# written 27100 dcm files, time elapsed: 0h 49m 9s
# processing batch 272
# written 27200 dcm files, time elapsed: 0h 49m 18s
# processing batch 273
# written 27300 dcm files, time elapsed: 0h 49m 25s
# processing batch 274
# written 27400 dcm files, time elapsed: 0h 49m 36s
# processing batch 275
# written 27500 dcm files, time elapsed: 0h 49m 48s
# processing batch 276
# written 27600 dcm files, time elapsed: 0h 50m 4s
# processing batch 277
# written 27700 dcm files, time elapsed: 0h 50m 15s
# processing batch 278
# written 27800 dcm files, time elapsed: 0h 50m 25s
# processing batch 279
# written 27900 dcm files, time elapsed: 0h 50m 34s
# processing batch 280
# written 28000 dcm files, time elapsed: 0h 50m 47s
# processing batch 281
# written 28100 dcm files, time elapsed: 0h 50m 56s
# processing batch 282
# written 28200 dcm files, time elapsed: 0h 51m 4s
# processing batch 283
# written 28300 dcm files, time elapsed: 0h 51m 18s
# processing batch 284
# written 28400 dcm files, time elapsed: 0h 51m 25s
# processing batch 285
# written 28500 dcm files, time elapsed: 0h 51m 34s
# processing batch 286
# written 28600 dcm files, time elapsed: 0h 51m 41s
# processing batch 287
# written 28700 dcm files, time elapsed: 0h 51m 55s
# processing batch 288
# written 28800 dcm files, time elapsed: 0h 52m 9s
# processing batch 289
# written 28900 dcm files, time elapsed: 0h 52m 18s
# processing batch 290
# written 29000 dcm files, time elapsed: 0h 52m 29s
# processing batch 291
# written 29100 dcm files, time elapsed: 0h 52m 37s
# processing batch 292
# written 29200 dcm files, time elapsed: 0h 52m 46s
# processing batch 293
# written 29300 dcm files, time elapsed: 0h 52m 54s
# processing batch 294
# written 29400 dcm files, time elapsed: 0h 53m 14s
# processing batch 295
# written 29500 dcm files, time elapsed: 0h 53m 26s
# processing batch 296
# written 29600 dcm files, time elapsed: 0h 53m 35s
# processing batch 297
# written 29700 dcm files, time elapsed: 0h 53m 48s
# processing batch 298
# written 29800 dcm files, time elapsed: 0h 54m 2s
# processing batch 299
# written 29900 dcm files, time elapsed: 0h 54m 18s
# processing batch 300
# written 30000 dcm files, time elapsed: 0h 54m 54s
# processing batch 301
# written 30100 dcm files, time elapsed: 0h 55m 32s
# processing batch 302
# written 30200 dcm files, time elapsed: 0h 56m 35s
# processing batch 303
# written 30300 dcm files, time elapsed: 0h 57m 24s
# processing batch 304
# written 30400 dcm files, time elapsed: 0h 58m 10s
# processing batch 305
# written 30500 dcm files, time elapsed: 0h 59m 6s
# processing batch 306
# written 30600 dcm files, time elapsed: 0h 59m 45s
# processing batch 307
# written 30700 dcm files, time elapsed: 1h 0m 30s
# processing batch 308
# written 30800 dcm files, time elapsed: 1h 1m 18s
# processing batch 309
# written 30900 dcm files, time elapsed: 1h 2m 8s
# processing batch 310
# written 31000 dcm files, time elapsed: 1h 3m 0s
# processing batch 311
# written 31100 dcm files, time elapsed: 1h 4m 13s
# processing batch 312
# written 31200 dcm files, time elapsed: 1h 5m 11s
# processing batch 313
# written 31300 dcm files, time elapsed: 1h 5m 54s
# processing batch 314
# written 31400 dcm files, time elapsed: 1h 7m 1s
# processing batch 315
# written 31500 dcm files, time elapsed: 1h 8m 3s
# processing batch 316
# written 31600 dcm files, time elapsed: 1h 8m 39s
# processing batch 317
# written 31700 dcm files, time elapsed: 1h 9m 23s
# processing batch 318
# written 31800 dcm files, time elapsed: 1h 10m 7s
# processing batch 319
# written 31900 dcm files, time elapsed: 1h 11m 8s
# processing batch 320
# written 32000 dcm files, time elapsed: 1h 11m 44s
# processing batch 321
# written 32100 dcm files, time elapsed: 1h 12m 33s
# processing batch 322
# written 32200 dcm files, time elapsed: 1h 13m 15s
# processing batch 323
# written 32300 dcm files, time elapsed: 1h 13m 55s
# processing batch 324
# written 32400 dcm files, time elapsed: 1h 14m 56s
# processing batch 325
# written 32500 dcm files, time elapsed: 1h 15m 37s
# processing batch 326
# written 32600 dcm files, time elapsed: 1h 16m 25s
# processing batch 327
# written 32700 dcm files, time elapsed: 1h 17m 8s
# processing batch 328
# written 32800 dcm files, time elapsed: 1h 18m 6s
# processing batch 329
# written 32900 dcm files, time elapsed: 1h 18m 37s
# processing batch 330
# written 33000 dcm files, time elapsed: 1h 19m 19s
# processing batch 331
# written 33100 dcm files, time elapsed: 1h 20m 13s
# processing batch 332
# written 33200 dcm files, time elapsed: 1h 20m 47s
# processing batch 333
# written 33300 dcm files, time elapsed: 1h 21m 26s
# processing batch 334
# written 33400 dcm files, time elapsed: 1h 22m 16s
# processing batch 335
# written 33500 dcm files, time elapsed: 1h 23m 6s
# processing batch 336
# written 33600 dcm files, time elapsed: 1h 24m 1s
# processing batch 337
# written 33700 dcm files, time elapsed: 1h 24m 53s
# processing batch 338
# written 33800 dcm files, time elapsed: 1h 25m 39s
# processing batch 339
# written 33900 dcm files, time elapsed: 1h 26m 14s
# processing batch 340
# written 34000 dcm files, time elapsed: 1h 27m 2s
# processing batch 341
# written 34100 dcm files, time elapsed: 1h 27m 38s
# processing batch 342
# written 34200 dcm files, time elapsed: 1h 28m 19s
# processing batch 343
# written 34300 dcm files, time elapsed: 1h 29m 7s
# processing batch 344
# written 34400 dcm files, time elapsed: 1h 29m 57s
# processing batch 345
# written 34500 dcm files, time elapsed: 1h 30m 44s
# processing batch 346
# written 34600 dcm files, time elapsed: 1h 31m 25s
# processing batch 347
# written 34700 dcm files, time elapsed: 1h 32m 11s
# processing batch 348
# written 34800 dcm files, time elapsed: 1h 33m 9s
# processing batch 349
# written 34900 dcm files, time elapsed: 1h 35m 19s
# processing batch 350
# written 35000 dcm files, time elapsed: 1h 36m 8s
# processing batch 351
# written 35100 dcm files, time elapsed: 1h 36m 30s
# processing batch 352
# written 35200 dcm files, time elapsed: 1h 37m 33s
# processing batch 353
# written 35300 dcm files, time elapsed: 1h 38m 19s
# processing batch 354
# written 35400 dcm files, time elapsed: 1h 38m 21s
# processing batch 355
# written 35500 dcm files, time elapsed: 1h 38m 22s
# processing batch 356
# written 35600 dcm files, time elapsed: 1h 38m 24s
# processing batch 357
# written 35700 dcm files, time elapsed: 1h 38m 25s
# processing batch 358
# written 35800 dcm files, time elapsed: 1h 38m 27s
# processing batch 359
# written 35900 dcm files, time elapsed: 1h 38m 28s
# processing batch 360
# written 36000 dcm files, time elapsed: 1h 38m 58s
# processing batch 361
# written 36100 dcm files, time elapsed: 1h 40m 15s
# processing batch 362
# written 36200 dcm files, time elapsed: 1h 40m 49s
# processing batch 363
# written 36300 dcm files, time elapsed: 1h 41m 35s
# processing batch 364
# written 36400 dcm files, time elapsed: 1h 44m 7s
# processing batch 365
# written 36500 dcm files, time elapsed: 1h 45m 49s
# processing batch 366
# written 36600 dcm files, time elapsed: 1h 48m 6s
# processing batch 367
# written 36700 dcm files, time elapsed: 1h 50m 53s
# processing batch 368
# written 36800 dcm files, time elapsed: 1h 52m 45s
# processing batch 369
# written 36900 dcm files, time elapsed: 1h 54m 45s
# processing batch 370
# written 37000 dcm files, time elapsed: 1h 56m 25s
# processing batch 371
# written 37100 dcm files, time elapsed: 1h 57m 26s
# processing batch 372
# written 37200 dcm files, time elapsed: 1h 58m 36s
# processing batch 373
# written 37300 dcm files, time elapsed: 1h 59m 5s
# processing batch 374
# written 37400 dcm files, time elapsed: 1h 59m 32s
# processing batch 375
# written 37500 dcm files, time elapsed: 2h 0m 0s
# processing batch 376
# written 37600 dcm files, time elapsed: 2h 0m 29s
# processing batch 377
# written 37700 dcm files, time elapsed: 2h 0m 58s
# processing batch 378
# written 37800 dcm files, time elapsed: 2h 1m 28s
# processing batch 379
# written 37900 dcm files, time elapsed: 2h 1m 55s
# processing batch 380
# written 38000 dcm files, time elapsed: 2h 2m 20s
# processing batch 381
# written 38100 dcm files, time elapsed: 2h 2m 45s
# processing batch 382
# written 38200 dcm files, time elapsed: 2h 3m 12s
# processing batch 383
# written 38300 dcm files, time elapsed: 2h 3m 38s
# processing batch 384
# written 38400 dcm files, time elapsed: 2h 4m 6s
# processing batch 385
# written 38500 dcm files, time elapsed: 2h 4m 35s
# processing batch 386
# written 38600 dcm files, time elapsed: 2h 5m 3s
# processing batch 387
# written 38700 dcm files, time elapsed: 2h 5m 34s
# processing batch 388
# written 38800 dcm files, time elapsed: 2h 6m 7s
# processing batch 389
# written 38900 dcm files, time elapsed: 2h 6m 39s
# processing batch 390
# written 39000 dcm files, time elapsed: 2h 7m 10s
# processing batch 391
# written 39100 dcm files, time elapsed: 2h 7m 43s
# processing batch 392
# written 39200 dcm files, time elapsed: 2h 8m 15s
# processing batch 393
# written 39300 dcm files, time elapsed: 2h 8m 44s
# processing batch 394
# written 39400 dcm files, time elapsed: 2h 9m 9s
# processing batch 395
# written 39500 dcm files, time elapsed: 2h 9m 31s
# processing batch 396
# written 39600 dcm files, time elapsed: 2h 9m 53s
# processing batch 397
# written 39700 dcm files, time elapsed: 2h 10m 20s
# processing batch 398
# written 39800 dcm files, time elapsed: 2h 10m 43s
# processing batch 399
# written 39900 dcm files, time elapsed: 2h 11m 4s
# processing batch 400
# written 40000 dcm files, time elapsed: 2h 11m 15s
# processing batch 401
# written 40100 dcm files, time elapsed: 2h 11m 32s
# processing batch 402
# written 40200 dcm files, time elapsed: 2h 11m 48s
# processing batch 403
# written 40300 dcm files, time elapsed: 2h 12m 5s
# processing batch 404
# written 40400 dcm files, time elapsed: 2h 12m 15s
# processing batch 405
# written 40500 dcm files, time elapsed: 2h 12m 18s
# processing batch 406
# written 40600 dcm files, time elapsed: 2h 12m 21s
# processing batch 407
# written 40700 dcm files, time elapsed: 2h 12m 24s
# processing batch 408
# written 40800 dcm files, time elapsed: 2h 12m 27s
# processing batch 409
# written 40900 dcm files, time elapsed: 2h 12m 30s
# processing batch 410
# written 41000 dcm files, time elapsed: 2h 12m 33s
# processing batch 411
# written 41100 dcm files, time elapsed: 2h 12m 36s
# processing batch 412
# written 41200 dcm files, time elapsed: 2h 12m 39s
# processing batch 413
# written 41300 dcm files, time elapsed: 2h 12m 42s
# processing batch 414
# written 41400 dcm files, time elapsed: 2h 12m 44s
# processing batch 415
# written 41500 dcm files, time elapsed: 2h 12m 47s
# processing batch 416
# written 41600 dcm files, time elapsed: 2h 12m 50s
# processing batch 417
# written 41700 dcm files, time elapsed: 2h 12m 53s
# processing batch 418
# written 41800 dcm files, time elapsed: 2h 12m 56s
# processing batch 419
# written 41900 dcm files, time elapsed: 2h 12m 59s
# processing batch 420
# written 42000 dcm files, time elapsed: 2h 13m 2s
# processing batch 421
# written 42100 dcm files, time elapsed: 2h 13m 4s
# processing batch 422
# written 42200 dcm files, time elapsed: 2h 13m 8s
# processing batch 423
# written 42300 dcm files, time elapsed: 2h 13m 11s
# processing batch 424
# written 42400 dcm files, time elapsed: 2h 13m 13s
# processing batch 425
# written 42500 dcm files, time elapsed: 2h 13m 17s
# processing batch 426
# written 42600 dcm files, time elapsed: 2h 13m 20s
# processing batch 427
# written 42700 dcm files, time elapsed: 2h 13m 23s
# processing batch 428
# written 42800 dcm files, time elapsed: 2h 13m 26s
# processing batch 429
# written 42900 dcm files, time elapsed: 2h 13m 29s
# processing batch 430
# written 43000 dcm files, time elapsed: 2h 13m 31s
# processing batch 431
# written 43100 dcm files, time elapsed: 2h 13m 34s
# processing batch 432
# written 43200 dcm files, time elapsed: 2h 13m 37s
# processing batch 433
# written 43300 dcm files, time elapsed: 2h 13m 40s
